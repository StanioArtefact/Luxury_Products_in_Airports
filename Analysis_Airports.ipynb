# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ### Import Changi data

# %%
changi = pd.read_csv('data/Changi_Traffic.csv', sep=',')

# %% [markdown]
# ### Import Japan data

# %%
japan = pd.read_csv('data/Japan_Airports.csv', sep=',')

# %% [markdown]
# ### Import Worldwide data

# %%
worldwide = pd.read_csv('data/Traffic - Worldwide_Ranking.csv', sep=',')

# %% [markdown]
# ### Import Airports data

# %%
column_names = [
    "Airport_ID",            
    "Name",                   
    "City",                   
    "Country",                
    "IATA",                   
    "ICAO",                   
    "Latitude",               
    "Longitude",              
    "Altitude",               
    "Timezone",               
    "DST",                    
    "Tz_database_time_zone", 
    "Type",                   
    "Source"                  
]

airports = pd.read_csv("data/airports.dat.txt", header=None, names=column_names)

# %% [markdown]
# ## Process data

# %% [markdown]
# ### Remove NaN values

# %%
# Remove NaN in changi dataframe
changi.dropna(inplace=True)

# Remove NaN in japan dataframe
japan.dropna(inplace=True)

# %% [markdown]
# ### Changi Process

# %% [markdown]
# #### Rename the column in Changi to indicate that it contains data related to the number of passengers

# %%
changi.rename(columns={'Unnamed: 1' : 'Number of Passengers (in Millions)'})
# Out:
#              Month Number of Passengers (in Millions)
# 0     January 2024                              5 430
# 1    February 2024                              5 350
# 2       March 2024                              5 730
# 3       April 2024                              5 400
# 4         May 2024                              5 480
# 5        June 2024                              5 620
# 6        July 2024                              5 700
# 7      August 2024                              5 730
# 8   September 2024                              5 400
# 9     October 2024                              5 650
# 10   November 2024                              5 740
# 11   December 2024                              6 410
# 12    January 2025                              6 160
# 13   February 2025                              5 440

# %% [markdown]
# ### Worldwide Process

# %% [markdown]
# #### Rename all the columns

# %%
worldwide.columns = ['Rank', 'Airport_Name', 'Location', 'Country', 'Code', 'Number_of_Passengers', 'Rank_Change', '%_Change']

# %% [markdown]
# #### Remove useless columns

# %%
worldwide.drop(columns=['Code', 'Rank_Change', '%_Change'], inplace=True)

# %% [markdown]
# #### Clean the column Number_of_Passengers

# %% [markdown]
# #### Remove the number between []

# %%
# Remove the [] and the number inside
worldwide['Number_of_Passengers'] = worldwide['Number_of_Passengers'].str.replace(r'\[\d+\]', '', regex=True)

# %% [markdown]
# #### Change the format of the cell to print Number in M instead of the number

# %%
# Remove the thousands separator , 
worldwide['Number_of_Passengers'] = worldwide['Number_of_Passengers'].str.replace(',', '').astype(int)

# %%
# Convert to millions
worldwide['Number_of_Passengers'] = worldwide['Number_of_Passengers'].apply(lambda x: f"{x / 1_000_000:.2f}M")

# %% [markdown]
# #### Merge worldwide and airports to get the Latitude information and the Longitude information

# %%
# Get all the airports that have the same name between airports and worldwide dataframes
# len(set(airports['Name']).intersection(set(worldwide['Airport_Name'])))

# %%
# Get all the airports that have different names between airports and worldwide dataframes
# set(worldwide['Airport_Name']).difference(set(airports['Name']))

# %%
# Check for each airport name
# airports[airports['Name'].str.contains('Reid')]

# %%
# Create a mapping table with on the left the airports names in the airports dataframe that need to be changed, and the equivalence in worldwide
mapping_airports = {
    'Charles de Gaulle International Airport' : 'Charles de Gaulle Airport', 
    'Chengdu Shuangliu International Airport' : 'Chengdu Tianfu International Airport', 
    'Chhatrapati Shivaji International Airport' : 'Chhatrapati Shivaji Maharaj International Airport', 
    'Frankfurt am Main Airport' : 'Frankfurt Airport',
    'George Bush Intercontinental Houston Airport' : 'George Bush Intercontinental Airport',
    'Hartsfield Jackson Atlanta International Airport' : 'Hartsfield–Jackson Atlanta International Airport',
    'London Heathrow Airport' : 'Heathrow Airport', 
    'John F Kennedy International Airport' : 'John F. Kennedy International Airport',
    'Barcelona International Airport' : 'Josep Tarradellas Barcelona–El Prat Airport',
    "Chicago O'Hare International Airport" : "O'Hare International Airport",
    'Roma Airport' : 'Rome Fiumicino Airport',
    'Seattle Tacoma International Airport' : 'Seattle–Tacoma International Airport',
    'Incheon International Airport' : 'Seoul Incheon International Airport',
    'Soekarno-Hatta International Airport' : 'Soekarno–Hatta International Airport',
    'Tokyo Haneda International Airport' : 'Tokyo Haneda Airport',
    'Lester B. Pearson International Airport' : 'Toronto Pearson International Airport', 
    'McCarran International Airport' : 'Harry Reid International Airport',
    'Licenciado Benito Juarez International Airport' :  'Mexico City International Airport'
}

# %%
# Replace the values included in the mapping table by their equivalent
airports['Name'] = airports['Name'].replace(mapping_airports)

# %%
airports.head()
# Out:
#    Airport_ID                                         Name          City  \
# 0           1                               Goroka Airport        Goroka
# 1           2                               Madang Airport        Madang
# 2           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3           4                               Nadzab Airport        Nadzab
# 4           5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude Timezone DST  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20       10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#   Tz_database_time_zone     Type       Source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
# Rename Airport_Name from worldwide to match with airports Name
worldwide.rename(columns={'Airport_Name' : 'Name'}, inplace=True)

# Merge worldwide and airports on the column Name
world_airports = pd.merge(worldwide, airports, how='left', on='Name')

# %% [markdown]
# ### Keep only the relevant columns

# %%
# Create a list of columns to keep
to_keep = ['Rank', 'Name', 'City', 'Country_x', 'Number_of_Passengers', 'Latitude', 'Longitude']

# Keep the columns included in this list
world_airports = world_airports[to_keep]

# Rename the column Country_x into Country
world_airports.rename(columns={'Country_x' : 'Country'}, inplace=True)

# %% [markdown]
# ## Export

# %% [markdown]
# ### world_airports dataframe

# %%
world_airports
# Out:
#     Rank                                               Name  \
# 0      1   Hartsfield–Jackson Atlanta International Airport
# 1      2                        Dubai International Airport
# 2      3            Dallas Fort Worth International Airport
# 3      4                               Tokyo Haneda Airport
# 4      5                                   Heathrow Airport
# 5      6                       Denver International Airport
# 6      7                       O'Hare International Airport
# 7      8                                   Istanbul Airport
# 8      9                Indira Gandhi International Airport
# 9     10              Shanghai Pudong International Airport
# 10    11                  Los Angeles International Airport
# 11    12             Guangzhou Baiyun International Airport
# 12    13                Seoul Incheon International Airport
# 13    14                          Charles de Gaulle Airport
# 14    15                           Singapore Changi Airport
# 15    16              Beijing Capital International Airport
# 16    17                         Amsterdam Airport Schiphol
# 17    18               Adolfo Suárez Madrid–Barajas Airport
# 18    19              John F. Kennedy International Airport
# 19    20              Shenzhen Bao'an International Airport
# 20    21                               Suvarnabhumi Airport
# 21    22                                  Frankfurt Airport
# 22    23            Charlotte Douglas International Airport
# 23    24                   Harry Reid International Airport
# 24    25                      Orlando International Airport
# 25    26                 Kuala Lumpur International Airport
# 26    27                        Miami International Airport
# 27    28        Josep Tarradellas Barcelona–El Prat Airport
# 28    29               Chengdu Tianfu International Airport
# 29    30               Soekarno–Hatta International Airport
# 30    31  Chhatrapati Shivaji Maharaj International Airport
# 31    32                    Hong Kong International Airport
# 32    33                        Hamad International Airport
# 33    34               Seattle–Tacoma International Airport
# 34    35           Phoenix Sky Harbor International Airport
# 35    36                San Francisco International Airport
# 36    37                 Ninoy Aquino International Airport
# 37    38               Beijing Daxing International Airport
# 38    39                             Rome Fiumicino Airport
# 39    40               King Abdulaziz International Airport
# 40    41               Newark Liberty International Airport
# 41    42           Chongqing Jiangbei International Airport
# 42    43               George Bush Intercontinental Airport
# 43    44            Hangzhou Xiaoshan International Airport
# 44    45            Shanghai Hongqiao International Airport
# 45    46            Kunming Changshui International Airport
# 46    47               Xi'an Xianyang International Airport
# 47    48              Toronto Pearson International Airport
# 48    49                    El Dorado International Airport
# 49    50                  Mexico City International Airport
#
#                  City               Country Number_of_Passengers   Latitude  \
# 0             Atlanta         United States              108.07M  33.636700
# 1               Dubai  United Arab Emirates               92.30M  25.252800
# 2   Dallas-Fort Worth         United States               87.82M  32.896801
# 3               Tokyo                 Japan               85.00M  35.552299
# 4              London        United Kingdom               83.88M  51.470600
# 5              Denver         United States               82.36M  39.861698
# 6             Chicago         United States               80.04M  41.978600
# 7            Istanbul                Turkey               79.99M  41.275278
# 8               Delhi                 India               77.82M  28.566500
# 9            Shanghai                 China               76.79M  31.143400
# 10        Los Angeles         United States               76.59M  33.942501
# 11          Guangzhou                 China               76.36M  23.392401
# 12              Seoul           South Korea               70.67M  37.469101
# 13              Paris                France               70.29M  49.012798
# 14          Singapore             Singapore               67.70M   1.350190
# 15            Beijing                 China               67.37M  40.080101
# 16          Amsterdam           Netherlands               66.83M  52.308601
# 17             Madrid                 Spain               66.20M  40.471926
# 18           New York         United States               63.27M  40.639801
# 19           Shenzhen                 China               61.48M  22.639299
# 20            Bangkok              Thailand               60.00M  13.681100
# 21          Frankfurt               Germany               59.36M  50.033333
# 22          Charlotte         United States               58.81M  35.214001
# 23          Las Vegas         United States               58.45M  36.080101
# 24            Orlando         United States               57.21M  28.429399
# 25       Kuala Lumpur              Malaysia               57.04M   2.745580
# 26              Miami         United States               55.93M  25.793200
# 27          Barcelona                 Spain               55.03M  41.297100
# 28            Chengdu                 China               54.91M  30.578501
# 29            Jakarta             Indonesia               54.81M  -6.125570
# 30             Mumbai                 India               54.80M  19.088699
# 31          Hong Kong             Hong Kong               53.10M  22.308901
# 32               Doha                 Qatar               52.70M  25.273056
# 33            Seattle         United States               52.64M  47.449001
# 34            Phoenix         United States               52.33M  33.434299
# 35      San Francisco         United States               52.29M  37.618999
# 36             Manila           Philippines               50.10M  14.508600
# 37            Beijing                 China               49.44M  39.509945
# 38               Roma                 Italy               49.20M -26.545000
# 39             Jeddah          Saudi Arabia               49.10M  21.679600
# 40             Newark         United States               48.85M  40.692501
# 41          Chongqing                 China               48.68M  29.719200
# 42            Houston         United States               48.45M  29.984400
# 43           Hangzhou                 China               48.05M  30.229500
# 44           Shanghai                 China               47.94M  31.197901
# 45            Kunming                 China               47.18M  25.101944
# 46              Xi'an                 China               47.03M  34.447102
# 47            Toronto                Canada               46.80M  43.677200
# 48             Bogota              Colombia               45.82M   4.701590
# 49        Mexico City                Mexico               45.36M  19.436300
#
#      Longitude
# 0   -84.428101
# 1    55.364399
# 2   -97.038002
# 3   139.779999
# 4    -0.461941
# 5  -104.672997
# 6   -87.904800
# 7    28.751944
# 8    77.103104
# 9   121.805000
# 10 -118.407997
# 11  113.299004
# 12  126.450996
# 13    2.550000
# 14  103.994003
# 15  116.584999
# 16    4.763890
# 17   -3.562640
# 18  -73.778900
# 19  113.810997
# 20  100.747002
# 21    8.570556
# 22  -80.943100
# 23 -115.152000
# 24  -81.308998
# 25  101.709999
# 26  -80.290604
# 27    2.078460
# 28  103.946999
# 29  106.655998
# 30   72.867897
# 31  113.915001
# 32   51.608056
# 33 -122.308998
# 34 -112.012001
# 35 -122.375000
# 36  121.019997
# 37  116.410920
# 38  148.774994
# 39   39.156502
# 40  -74.168701
# 41  106.641998
# 42  -95.341400
# 43  120.433998
# 44  121.335999
# 45  102.929167
# 46  108.751999
# 47  -79.630600
# 48  -74.146900
# 49  -99.072098

# %%
world_airports.to_csv('world_airports.csv')
